# %% [markdown]
# # Content Images

# %%
import os
os.listdir(".")

if "val2017" not in os.listdir("."):
  # !wget http://images.cocodataset.org/zips/val2017.zip val2017.zip
  # !unzip val2017.zip
else:
  print("already have val2017")
# Out:
# already have val2017

# %%
# coco train2014, if you prefer to use large dataset, you can use this

# import os
# os.listdir(".")

# if "train2014" not in os.listdir("."):
#   !wget http://images.cocodataset.org/zips/train2014.zip -O train2014.zip
#   !unzip train2014.zip
# else:
#   print("already have train2014")

# %% [markdown]
# # Style Images

# %%
# %%bash
# mkdir -p style
# cd style
#
# wget -q \
#   https://uploads2.wikiart.org/images/claude-monet/haystacks-at-giverny-the-evening-sun.jpg!Large.jpg \
#   -O the_Evening_Sun.jpg
#
# wget -q \
#   https://i.pinimg.com/originals/7c/42/c9/7c42c9e25608ffb8151cd3b03d23b8e8.png \
#   -O Plum_Trees_in_Blossom.jpg
#
# wget -q \
#   https://pbs.twimg.com/media/Es87tLLU0AEqp01.jpg \
#   -O picasso_portraits.jpg
#
# wget -q \
#   https://upload.wikimedia.org/wikipedia/commons/thumb/e/eb/Claude_Monet_-_Three_Fishing_Boats_-_Google_Art_Project.jpg/968px-Claude_Monet_-_Three_Fishing_Boats_-_Google_Art_Project.jpg \
#   -O Three_Fishing_Boats.jpg
#
# wget -q \
#   https://lh5.ggpht.com/VfIcalSj6uchq9kiaA3ink6gFg1FaGtxqf85he0MQH2QF89_XFfT6Tn48zBFVQ \
#   -O Bicentennial_Print.jpg
#
# wget -q \
#   https://images.fineartamerica.com/images/artworkimages/mediumlarge/3/starry-night-print-by-vincent-van-gogh-vincent-van-gogh.jpg \
#   -O starry-night.jpg
#
# wget -q \
#   https://upload.wikimedia.org/wikipedia/commons/thumb/f/f4/The_Scream.jpg/471px-The_Scream.jpg \
#   -O the_scream.jpg
#
# wget -q \
#   https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Egon_Schiele_-_Edith_with_Striped_Dress%2C_Sitting_-_Google_Art_Project.jpg/477px-Egon_Schiele_-_Edith_with_Striped_Dress%2C_Sitting_-_Google_Art_Project.jpg \
#   -O Sitting.jpg
#
# wget -q \
#   https://m.media-amazon.com/images/I/71Ilp0TUT4L._AC_SY550_.jpg \
#   -O horses_on_the_seashore.jpg
#
# wget -q \
#   https://github.com/pytorch/examples/blob/master/fast_neural_style/images/style-images/mosaic.jpg?raw=true \
#   -O mosaic.jpg
#
# wget -q \
#   https://pbs.twimg.com/media/EjQGppGXkAYerCv.jpg \
#   -O yes_yes_yes.jpg
#
# wget -q \
#   https://images-na.ssl-images-amazon.com/images/I/418cEZfh8-L.jpg \
#   -O minecraft.jpg
#
# wget -q \
#   https://miro.medium.com/max/1023/1*iqmf52QY3q6n9j-PUEgVyQ.jpeg \
#   -O hive.jpg
#
# wget -q \
#   https://www.sciencenews.org/wp-content/uploads/2020/05/060620_reviews_feat-1028x579.jpg \
#   -O tree_ring.jpg
#
# wget -q \
#   "https://media.istockphoto.com/illustrations/melted-crayons-art-on-canvas-illustration-id160142363?k=6&m=160142363&s=612x612&w=0&h=L-ggzG61TAX5qU6nyBfHD_FbYAyAu4QUwJLWgIZrJSc=" \
#   -O wax.jpg

# %%
import glob
import matplotlib.pyplot as plt
import PIL
import numpy as np

for img_path in glob.glob("./style/*.jpg"):
  print(img_path)
  img = PIL.Image.open(img_path).convert('RGB')
  img = np.asarray(img)
  
  print("shape : ", img.shape)
  plt.imshow(img)
  plt.show()
# Out:
# ./style/the_Evening_Sun.jpg
# shape :  (595, 750, 3)
# ./style/yes_yes_yes.jpg
# shape :  (661, 1185, 3)
# ./style/Bicentennial_Print.jpg
# shape :  (512, 352, 3)
# ./style/picasso_portraits.jpg
# shape :  (822, 632, 3)
# ./style/horses_on_the_seashore.jpg
# shape :  (550, 407, 3)
# ./style/starry-night.jpg
# shape :  (717, 900, 3)
# ./style/Three_Fishing_Boats.jpg
# shape :  (768, 968, 3)
# ./style/Plum_Trees_in_Blossom.jpg
# shape :  (544, 750, 3)
# ./style/wax.jpg
# shape :  (493, 612, 3)
# ./style/minecraft.jpg
# shape :  (500, 500, 3)
# ./style/mosaic.jpg
# shape :  (391, 470, 3)
# ./style/hive.jpg
# shape :  (682, 1023, 3)
# ./style/the_scream.jpg
# shape :  (600, 471, 3)
# ./style/Sitting.jpg
# shape :  (600, 477, 3)
# ./style/tree_ring.jpg
# shape :  (579, 1028, 3)

# %% [markdown]
# # Test Images

# %%
# !wget https://i.kym-cdn.com/entries/icons/original/000/013/564/doge.jpg -O doge.jpg
# Out:
# --2021-08-30 17:38:36--  https://i.kym-cdn.com/entries/icons/original/000/013/564/doge.jpg
# Resolving i.kym-cdn.com (i.kym-cdn.com)... 203.77.190.60, 203.77.191.14
# Connecting to i.kym-cdn.com (i.kym-cdn.com)|203.77.190.60|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 70632 (69K) [image/jpeg]
# Saving to: ‘doge.jpg’
#
# doge.jpg            100%[===================>]  68.98K  --.-KB/s    in 0.06s
#
# 2021-08-30 17:38:36 (1.18 MB/s) - ‘doge.jpg’ saved [70632/70632]

# %%
# !wget https://github.com/pytorch/examples/blob/master/fast_neural_style/images/content-images/amber.jpg?raw=true -O amber.jpg
# Out:
# --2021-08-30 17:38:36--  https://github.com/pytorch/examples/blob/master/fast_neural_style/images/content-images/amber.jpg?raw=true
# Resolving github.com (github.com)... 52.192.72.89
# Connecting to github.com (github.com)|52.192.72.89|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/pytorch/examples/raw/master/fast_neural_style/images/content-images/amber.jpg [following]
# --2021-08-30 17:38:36--  https://github.com/pytorch/examples/raw/master/fast_neural_style/images/content-images/amber.jpg
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/pytorch/examples/master/fast_neural_style/images/content-images/amber.jpg [following]
# --2021-08-30 17:38:37--  https://raw.githubusercontent.com/pytorch/examples/master/fast_neural_style/images/content-images/amber.jpg
# ...
